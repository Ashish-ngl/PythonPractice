# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-ngl/PythonPractice/blob/main/WorkingWithImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
img_path = "/content/drive/My Drive/Colab Notebooks/WorkingWithImage/pict.png"
pic = Image.open(img_path)
pic.show()

# %%
pic = Image.open(img_path)
pic.show()

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1366x698>

# %%
pic.size
# Out:
# (1366, 698)

# %%
pic.info
# Out:
# {'Software': 'gnome-screenshot',
#  'Creation Time': 'Mon 17 Feb 2025 05:07:06 PM IST'}

# %%
pic.load_read
# Out:
# <bound method PngImageFile.load_read of <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1366x698 at 0x7FC3303E5A50>>

# %%
pic.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>
